# %% [markdown]
# ## Training
#
# ```
# python -m cond_gan.train --image_dir=/home/mirjalil/data/mnist/ --gan_loss=vanilla  --fully_connected=0 --c_dim=10```

# %% [markdown]
# ### Conditional GAN with fully-connected layers in Generator and Discriminator

# %%
import sys
sys.path.append('../')
from cond_gan.train import parse, main

# %%
args = parse([
    '--image_dir=/home/mirjalil/data/mnist/',
    '--gan_loss=vanilla',
    '--fully_connected=1',
    '--c_dim=10'])

args
# Out:
# Namespace(batch_size=128, beta1=0.5, c_dim=10, checkpoint_dir='/tmp/checkpoints/05_05_2020-21_45_27', fully_connected=1, gan_loss='vanilla', hidden_dim=128, image_channels=1, image_dim=28, image_dir='/home/mirjalil/data/mnist/', learning_rate=0.0001, log_interval=100, nf_discriminator=8, nf_generator=64, ngpu=1, num_epochs=100, num_workers=1, p_drop=0.5, z_dim=50)

# %%
main(args)
# Out:
# Namespace(batch_size=128, beta1=0.5, c_dim=10, checkpoint_dir='/tmp/checkpoints/05_05_2020-21_45_27', fully_connected=1, gan_loss='vanilla', hidden_dim=128, image_channels=1, image_dim=28, image_dir='/home/mirjalil/data/mnist/', learning_rate=0.0001, log_interval=100, nf_discriminator=8, nf_generator=64, ngpu=1, num_epochs=100, num_workers=1, p_drop=0.5, z_dim=50)
# Device: cuda:1
# dataloader <torch.utils.data.dataloader.DataLoader object at 0x7f0d0da7b610>
# static_batch_z: torch.Size([50, 50])
# static_batch_c: torch.Size([50, 10])
# Epoch 1  /100 Iter 100/469 G: 0.8233 D: 0.3037
# Epoch 1  /100 Iter 200/469 G: 0.6588 D: 0.3941
# Epoch 1  /100 Iter 300/469 G: 0.7109 D: 0.3863
# Epoch 1  /100 Iter 400/469 G: 0.7721 D: 0.3804
# Epoch 2  /100 Iter 100/469 G: 0.7960 D: 0.4110
# Epoch 2  /100 Iter 200/469 G: 0.8845 D: 0.4108
# Epoch 2  /100 Iter 300/469 G: 1.0071 D: 0.3755
# Epoch 2  /100 Iter 400/469 G: 1.1066 D: 0.3261
# Epoch 3  /100 Iter 100/469 G: 1.5676 D: 0.2489
# ...

# %%
import IPython.display as display

display.Image(url='snapshots/conditional-gan-fc.png', width=300)
# Out:
# <img src="snapshots/conditional-gan-fc.png" width="300"/>

# %% [markdown]
# ### Conditional GAN with Convolutional Networks

# %%
import sys
sys.path.append('../')
from cond_gan.train import parse, main

args = parse([
    '--image_dir=/home/mirjalil/data/mnist/',
    '--gan_loss=vanilla',
    '--fully_connected=0',
    '--c_dim=10'])

args
# Out:
# Namespace(batch_size=128, beta1=0.5, c_dim=10, checkpoint_dir='/tmp/checkpoints/05_05_2020-22_36_10', fully_connected=0, gan_loss='vanilla', hidden_dim=128, image_channels=1, image_dim=28, image_dir='/home/mirjalil/data/mnist/', learning_rate=0.0001, log_interval=100, nf_discriminator=8, nf_generator=64, ngpu=1, num_epochs=100, num_workers=1, p_drop=0.5, z_dim=50)

# %%
main(args)
# Out:
# Namespace(batch_size=128, beta1=0.5, c_dim=10, checkpoint_dir='/tmp/checkpoints/05_05_2020-22_36_10', fully_connected=0, gan_loss='vanilla', hidden_dim=128, image_channels=1, image_dim=28, image_dir='/home/mirjalil/data/mnist/', learning_rate=0.0001, log_interval=100, nf_discriminator=8, nf_generator=64, ngpu=1, num_epochs=100, num_workers=1, p_drop=0.5, z_dim=50)
# Device: cuda:1
# dataloader <torch.utils.data.dataloader.DataLoader object at 0x7fab70c90710>
# static_batch_z: torch.Size([50, 50])
# static_batch_c: torch.Size([50, 10])
# Epoch 1  /100 Iter 100/469 G: 1.4386 D: 0.2820
# Epoch 1  /100 Iter 200/469 G: 2.2499 D: 0.1171
# Epoch 1  /100 Iter 300/469 G: 2.7876 D: 0.0827
# Epoch 1  /100 Iter 400/469 G: 2.7238 D: 0.0738
# Epoch 2  /100 Iter 100/469 G: 2.9782 D: 0.1208
# Epoch 2  /100 Iter 200/469 G: 2.0093 D: 0.1410
# Epoch 2  /100 Iter 300/469 G: 2.2568 D: 0.1718
# Epoch 2  /100 Iter 400/469 G: 1.7996 D: 0.1754
# Epoch 3  /100 Iter 100/469 G: 1.2914 D: 0.4104
# ...

# %%
import IPython.display as display

display.Image(url='snapshots/conditional-gan-conv.png', width=300)
# Out:
# <img src="snapshots/conditional-gan-conv.png" width="300"/>
